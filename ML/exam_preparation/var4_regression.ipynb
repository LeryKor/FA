# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("Financial Distress.csv")

# %% [markdown]
# Описание датасета

# %%
data.head()
# Out:
#    Company  Time  Financial Distress      x1        x2       x3       x4  \
# 0        1     1            0.010636  1.2810  0.022934  0.87454  1.21640
# 1        1     2           -0.455970  1.2700  0.006454  0.82067  1.00490
# 2        1     3           -0.325390  1.0529 -0.059379  0.92242  0.72926
# 3        1     4           -0.566570  1.1131 -0.015229  0.85888  0.80974
# 4        2     1            1.357300  1.0623  0.107020  0.81460  0.83593
#
#          x5        x6       x7  ...      x74    x75     x76     x77   x78  \
# 0  0.060940  0.188270  0.52510  ...   85.437  27.07  26.102  16.000  16.0
# 1 -0.014080  0.181040  0.62288  ...  107.090  31.31  30.194  17.000  16.0
# 2  0.020476  0.044865  0.43292  ...  120.870  36.07  35.273  17.000  15.0
# 3  0.076037  0.091033  0.67546  ...   54.806  39.80  38.377  17.167  16.0
# 4  0.199960  0.047800  0.74200  ...   85.437  27.07  26.102  16.000  16.0
#
#    x79  x80       x81  x82  x83
# 0  0.2   22  0.060390   30   49
# ...

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
X, y = data.drop(columns=["Financial Distress"]), data["Financial Distress"]

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.25, 
                                                    random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(f'MAE = {mean_absolute_error(y_test, y_pred)}')
print(f'MSE = {mean_squared_error(y_test, y_pred)}')
print(f'score = {model.score(X_test, y_test)}')
# Out:
# MAE = 0.789551602091675
# MSE = 18.27473113007768
# score = 0.08158179506890084

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
def polyFunction(deg):
  poly = PolynomialFeatures(degree=deg)
  poly_features_train = poly.fit_transform(X_train)
  poly_features_test = poly.fit_transform(X_test)
  binary = LinearRegression()
  binary.fit(poly_features_train, y_train)
  y_pred = binary.predict(poly_features_test)
  print(f'MAE = {mean_absolute_error(y_test, y_pred)}')
  print(f'MSE = {mean_squared_error(y_test, y_pred)}')
  return binary.score(poly_features_test, y_test)

# %%
# for j in [i for i in range(7)]:
for j in [0, 1, 2]:
  print(f'Степень полинома: {j}')
  print(f'score: {polyFunction(j)}')
# Out:
# Степень полинома: 0
# MAE = 1.1177709861524057
# MSE = 19.921302415427263
# score: -0.0011685903358353844
# Степень полинома: 1
# MAE = 0.7895533322553483
# MSE = 18.274829866664497
# score: 0.0815768329450709
# Степень полинома: 2
# MAE = 4630.652423234502
# MSE = 18009939598.655396
# score: -905110792.662566

# %% [markdown]
# Степень полинома лучше такая-то...

# %%
X_train.drop(columns=["x"+str(i) for i in range(51, 84)], inplace= True)
X_test.drop(columns=["x"+str(i) for i in range(51, 84)], inplace= True)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(f'MAE = {mean_absolute_error(y_test, y_pred)}')
print(f'MSE = {mean_squared_error(y_test, y_pred)}')
print(f'score = {model.score(X_test, y_test)}')
# Out:
# MAE = 0.8139861457537854
# MSE = 18.033598872358706
# score = 0.093700181583532

# %% [markdown]
# Лучше

# %%
X_train.drop(columns=["x"+str(i) for i in range(21, 51)], inplace= True)
X_test.drop(columns=["x"+str(i) for i in range(21, 51)], inplace= True)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(f'MAE = {mean_absolute_error(y_test, y_pred)}')
print(f'MSE = {mean_squared_error(y_test, y_pred)}')
print(f'score = {model.score(X_test, y_test)}')
# Out:
# MAE = 0.847041721096768
# MSE = 18.919672691824797
# score = 0.04916949487093192

# %% [markdown]
# хуже

# %% [markdown]
# Вывод...
