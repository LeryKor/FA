# %% [markdown]
# # Dask Delayed

# %% [markdown]
# Материалы:
# * Макрушин С.В. Лекция 13: Dask Delayed
# * https://docs.dask.org/en/latest/delayed.html
# * JESSE C. DANIEL. Data Science with Python and Dask.

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# ![](https://i.imgur.com/AwiN8y6.png)
# ![](https://i.imgur.com/ceY6guU.png)

# %% [markdown]
# 1. Напишите 2 функции, имитирующие CPU-bound задачу и IO-bound задачу:
#
# `cpu_task()`: генерирует 100 тыс. случайных чисел и возвращает их сумму (без использования `numpy`)
#
# `io_task()`: "спит" 0.1 сек, затем генерирует случайное число и возвращает его
#
# Замерьте время выполнения 100 последовательных вызовов каждой из этих функций. Распараллелив вычисления при помощи `dask.delayed`, сократите время выполнения. Исследуйте, как зависит время вычислений от выбранного планировщика `scheduler`.

# %%
import time
import random
import dask
from dask import delayed


def cpu_task():
    numbers = [random.random() for _ in range(100_000)]
    return sum(numbers)


def io_task():
    time.sleep(0.1)
    return random.random()


start_time = time.time()
for _ in range(100):
    cpu_task()
cpu_time = time.time() - start_time
print(f"CPU-bound task time: {cpu_time:.4f} seconds")

start_time = time.time()
for _ in range(100):
    io_task()
io_time = time.time() - start_time
print(f"IO-bound task time: {io_time:.4f} seconds")
# Out:
# CPU-bound task time: 1.2302 seconds
# IO-bound task time: 10.0188 seconds

# %%
@delayed
def cpu_task():
    numbers = [random.random() for _ in range(100_000)]
    return sum(numbers)

@delayed
def io_task():
    time.sleep(0.1)
    return random.random()


start_time = time.time()
tasks = []
for _ in range(100):
    tasks.append(cpu_task())
dask.delayed()(tasks).compute()
cpu_time = time.time() - start_time
print(f"CPU-bound task time: {cpu_time:.4f} seconds")

start_time = time.time()
for _ in range(100):
    io_task().compute()
io_time = time.time() - start_time
print(f"IO-bound task time: {io_time:.4f} seconds")
# Out:
# CPU-bound task time: 0.6940 seconds
# IO-bound task time: 10.0897 seconds

# %% [markdown]
# ## Лабораторная работа 14

# %% [markdown]
# 1. Напишите функцию, которая считывает файл формата xml из архива `reviewers_full.zip` и по данным этого файла формирует список словарей, содержащих следующие ключи: `username`, `name`, `sex`, `country`, `mail`, `registered`, `birthdate`, `name_prefix`, `country_code`. Часть из этих значений в исходном файле хранится в виде тэгов, часть - в виде атрибутов тэгов. Для конкретного человека какие-то из этих ключей могут отсутствовать.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from lxml import etree

def parse_xml_file(file_path):
    tree = etree.parse(file_path)
    root = tree.getroot()

    reviewers = []
    for user in root.findall('user'):
        reviewer_dict = {}
        reviewer_dict['id'] = user.findtext('id')
        reviewer_dict['username'] = user.findtext('username')
        reviewer_dict['name'] = user.findtext('name')
        reviewer_dict['sex'] = user.findtext('sex')
        reviewer_dict['country'] = user.findtext('country')
        reviewer_dict['mail'] = user.findtext('mail')
        reviewer_dict['registered'] = user.findtext('registered')
        reviewer_dict['birthdate'] = user.findtext('birthdate')

        if user.get('prefix') is not None:
            reviewer_dict['name_prefix'] = user.get('prefix')
        else:
            reviewer_dict['name_prefix'] = None

        country_elem = user.find('country')
        if country_elem is not None and country_elem.get('code') is not None:
            reviewer_dict['country_code'] = country_elem.get('code')
        else:
            reviewer_dict['country_code'] = None

        reviewers.append(reviewer_dict)

    return reviewers

# %% [markdown]
# 2. Измерьте время выполнения функции из задания 1 на всех файлах из архива. Ускорьте время выполнения, используя `dask.delayed`.

# %%
from dask import delayed

@delayed
def parse_xml_file_delayed(file_path):
    tree = etree.parse(file_path)
    root = tree.getroot()

    reviewers = []
    for user in root.findall('user'):
        reviewer_dict = {}
        reviewer_dict['id'] = user.findtext('id')
        reviewer_dict['username'] = user.findtext('username')
        reviewer_dict['name'] = user.findtext('name')
        reviewer_dict['sex'] = user.findtext('sex')
        reviewer_dict['country'] = user.findtext('country')
        reviewer_dict['mail'] = user.findtext('mail')
        reviewer_dict['registered'] = user.findtext('registered')
        reviewer_dict['birthdate'] = user.findtext('birthdate')

        if user.get('prefix') is not None:
            reviewer_dict['name_prefix'] = user.get('prefix')
        else:
            reviewer_dict['name_prefix'] = None

        country_elem = user.find('country')
        if country_elem is not None and country_elem.get('code') is not None:
            reviewer_dict['country_code'] = country_elem.get('code')
        else:
            reviewer_dict['country_code'] = None

        reviewers.append(reviewer_dict)

    return reviewers

# %%
# %%time
for i in range (5):
  parse_xml_file(f"/content/drive/MyDrive/tobd/reviewers_full/reviewers_full_{i}.xml");
# Out:
# CPU times: user 5.96 s, sys: 27.6 ms, total: 5.99 s
# Wall time: 6.08 s

# %%
# %%time
for i in range (5):
  parse_xml_file_delayed(f"/content/drive/MyDrive/tobd/reviewers_full/reviewers_full_{i}.xml").compute();
# Out:
# CPU times: user 4.86 s, sys: 100 ms, total: 4.96 s
# Wall time: 4.98 s

# %% [markdown]
# 3. Задекорируйте функцию из задания 1 при помощи `dask.delayed` и создайте список `reviewers`, состоящий из 5 объектов `delayed` (по одному объекту на файл). Из списка объектов `delayed`, создайте `dask.bag` при помощи метода `db.from_delayed`. Добавьте ключ `birth_year`, в котором хранится год рождения человека. Оставьте в выборке только тех людей, которые __наверняка__ моложе 1980 года. Преобразуйте поле `id` к целому типу.

# %%
import dask.bag as db

delayed = [parse_xml_file_delayed(f"/content/drive/MyDrive/tobd/reviewers_full/reviewers_full_{i}.xml") for i in range (5) ]
b = db.from_delayed(delayed).map(lambda x: {'birth_year': int(x['birthdate'][0:4]) if x and x.get('birthdate') else None, **x})
b = b.filter(lambda x: x['birth_year'] and x['birth_year'] > 1980 and x['birth_year'] is not None)
b = b.map(lambda x: {**x, 'id': int(x['id'])})

# %%
b.compute()
# Out:
# [{'birth_year': 1988,
#   'id': 556011,
#   'username': 'gabrielacalhoun',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1988-01-25',
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'birth_year': 1985,
#   'id': 1251087,
#   'username': 'qbaxter',
#   'name': None,
#   'sex': None,
#   'country': 'Norway',
#   'mail': 'qware@gmail.com',
#   'registered': None,
#   'birthdate': '1985-01-19',
#   'name_prefix': None,
#   'country_code': 'NO'},
#  {'birth_year': 2007,
#   'id': 250427,
#   'username': 'karen27',
#   'name': 'Jennifer Horne',
#   'sex': None,
#   'country': 'Cuba',
#   'mail': 'wjarvis@yahoo.com',
#   'registered': '2013-11-20',
#   'birthdate': '2007-04-30',
#   'name_prefix': None,
#   'country_code': 'CU'},
#  {'birth_year': 2005,
#   'id': 452355,
#   'username': 'smullen',
#   'name': 'Cynthia Johnson',
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2005-03-29',
#   'name_prefix': 'Miss',
#   'country_code': None},
#  {'birth_year': 1983,
#   'id': 2056668,
#   'username': 'franklinhancock',
#   'name': 'Michele Richards',
#   'sex': None,
#   'country': 'Namibia',
#   'mail': 'claudiamccoy@gmail.com',
#   'registered': '2009-08-12',
#   'birthdate': '1983-02-20',
#   'name_prefix': None,
#   'country_code': 'nan'},
#  {'birth_year': 2015,
#   'id': 356079,
#   'username': 'cdavis',
#   'name': None,
#   'sex': None,
#   'country': 'Qatar',
#   'mail': None,
#   'registered': None,
#   'birthdate': '2015-09-29',
#   'name_prefix': None,
#   'country_code': 'QA'},
#  {'birth_year': 1996,
#   'id': 1515495,
#   'username': 'ronaldgrimes',
#   'name': 'Rita Hodge',
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2003-07-03',
#   'birthdate': '1996-02-07',
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'birth_year': 2009,
#   'id': 169166,
#   'username': 'shannonbender',
#   'name': 'Sandy Morales',
#   'sex': 'F',
#   'country': 'Yemen',
#   'mail': None,
#   'registered': '2019-06-23',
#   'birthdate': '2009-04-21',
#   'name_prefix': None,
#   'country_code': 'YE'},
#  {'birth_year': 2017,
#   'id': 581536,
#   'username': 'caseyjustin',
#   'name': 'Jose Taylor',
#   'sex': None,
#   'country': None,
#   'mail': 'garretthaley@yahoo.com',
#   'registered': '2012-08-22',
#   'birthdate': '2017-12-20',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2001,
#   'id': 468627,
#   'username': 'dtaylor',
#   'name': None,
#   'sex': None,
#   'country': 'Andorra',
#   'mail': 'schaefercharles@hotmail.com',
#   'registered': None,
#   'birthdate': '2001-12-30',
#   'name_prefix': None,
#   'country_code': 'AD'},
#  {'birth_year': 1984,
#   'id': 1072593,
#   'username': 'christian74',
#   'name': 'Danielle Webster',
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1984-04-14',
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'birth_year': 1986,
#   'id': 1242867,
#   'username': 'christinegomez',
#   'name': None,
#   'sex': 'M',
#   'country': 'Netherlands',
#   'mail': 'xcrosby@yahoo.com',
#   'registered': '2016-07-01',
#   'birthdate': '1986-11-29',
#   'name_prefix': 'Dr.',
#   'country_code': 'NL'},
#  {'birth_year': 1990,
#   'id': 137854,
#   'username': 'hwoods',
#   'name': 'Nichole Maynard',
#   'sex': 'F',
#   'country': None,
#   'mail': 'jamesgalloway@hotmail.com',
#   'registered': None,
#   'birthdate': '1990-01-03',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1996,
#   'id': 2000498330,
#   'username': 'jenna30',
#   'name': None,
#   'sex': 'M',
#   'country': 'Anguilla',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1996-09-04',
#   'name_prefix': 'Dr.',
#   'country_code': 'AI'},
#  {'birth_year': 2020,
#   'id': 129958,
#   'username': 'robert57',
#   'name': None,
#   'sex': 'M',
#   'country': 'Qatar',
#   'mail': None,
#   'registered': '2008-09-19',
#   'birthdate': '2020-03-28',
#   'name_prefix': None,
#   'country_code': 'QA'},
#  {'birth_year': 2004,
#   'id': 19129,
#   'username': 'roberthoward',
#   'name': 'John Schaefer',
#   'sex': 'M',
#   'country': None,
#   'mail': 'connieyang@yahoo.com',
#   'registered': '2014-05-09',
#   'birthdate': '2004-09-01',
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'birth_year': 1987,
#   'id': 2549237,
#   'username': 'katherinemays',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1987-11-22',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2001,
#   'id': 791238,
#   'username': 'clarkjennifer',
#   'name': None,
#   'sex': None,
#   'country': 'Austria',
#   'mail': None,
#   'registered': None,
#   'birthdate': '2001-08-26',
#   'name_prefix': None,
#   'country_code': 'AT'},
#  {'birth_year': 1986,
#   'id': 4470,
#   'username': 'susanhoward',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'michaelhernandez@gmail.com',
#   'registered': None,
#   'birthdate': '1986-10-09',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1995,
#   'id': 25792,
#   'username': 'laurenjohnson',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': 'derrick15@hotmail.com',
#   'registered': None,
#   'birthdate': '1995-12-07',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2004,
#   'id': 359936,
#   'username': 'williambrooks',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2017-09-23',
#   'birthdate': '2004-03-15',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2009,
#   'id': 39992,
#   'username': 'carolyn39',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2009-05-25',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2008,
#   'id': 706608,
#   'username': 'pwatts',
#   'name': 'Tasha Kennedy',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2008-08-03',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1993,
#   'id': 766910,
#   'username': 'pdean',
#   'name': None,
#   'sex': 'F',
#   'country': 'Barbados',
#   'mail': 'janet77@hotmail.com',
#   'registered': None,
#   'birthdate': '1993-02-05',
#   'name_prefix': 'Mrs.',
#   'country_code': 'BB'},
#  {'birth_year': 1998,
#   'id': 43574191,
#   'username': 'heatheric',
#   'name': 'Michael Bentley',
#   'sex': None,
#   'country': 'Svalbard & Jan Mayen Islands',
#   'mail': None,
#   'registered': '2016-12-28',
#   'birthdate': '1998-12-21',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2016,
#   'id': 460228,
#   'username': 'nfitzgerald',
#   'name': 'Tiffany Hamilton',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2016-02-19',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1982,
#   'id': 409184,
#   'username': 'norma44',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2017-08-23',
#   'birthdate': '1982-05-08',
#   'name_prefix': 'Ms.',
#   'country_code': None},
#  {'birth_year': 2003,
#   'id': 1366053,
#   'username': 'audrey28',
#   'name': 'Jamie Harris',
#   'sex': 'F',
#   'country': None,
#   'mail': 'michelle59@hotmail.com',
#   'registered': '2018-01-03',
#   'birthdate': '2003-08-01',
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'birth_year': 2009,
#   'id': 206774,
#   'username': 'simsdan',
#   'name': 'Andrew Phillips',
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2018-10-29',
#   'birthdate': '2009-03-31',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'birth_year': 2021,
#   'id': 383346,
#   'username': 'williamhorn',
#   'name': 'Stephen Franco',
#   'sex': 'M',
#   'country': 'Liechtenstein',
#   'mail': 'jeffreyfreeman@gmail.com',
#   'registered': '2011-09-16',
#   'birthdate': '2021-05-28',
#   'name_prefix': 'Mr.',
#   'country_code': 'LI'},
#  {'birth_year': 2018,
#   'id': 160974,
#   'username': 'aaron85',
#   'name': 'Katie Miller',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2018-08-08',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2005,
#   'id': 1368735,
#   'username': 'zmontes',
#   'name': 'Michelle Chapman',
#   'sex': 'F',
#   'country': 'Bermuda',
#   'mail': 'lisa40@hotmail.com',
#   'registered': None,
#   'birthdate': '2005-10-29',
#   'name_prefix': None,
#   'country_code': 'BM'},
#  {'birth_year': 2009,
#   'id': 305531,
#   'username': 'katherinelopez',
#   'name': None,
#   'sex': None,
#   'country': 'Indonesia',
#   'mail': None,
#   'registered': '2016-03-03',
#   'birthdate': '2009-05-31',
#   'name_prefix': None,
#   'country_code': 'ID'},
#  {'birth_year': 1989,
#   'id': 464624,
#   'username': 'jennifercarter',
#   'name': 'Brittany Smith',
#   'sex': None,
#   'country': 'Djibouti',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1989-08-20',
#   'name_prefix': None,
#   'country_code': 'DJ'},
#  {'birth_year': 1993,
#   'id': 1363533,
#   'username': 'coltoncarter',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'donnamurphy@yahoo.com',
#   'registered': '2003-02-14',
#   'birthdate': '1993-08-28',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1996,
#   'id': 315055,
#   'username': 'amy70',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1996-05-17',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2021,
#   'id': 362983,
#   'username': 'cvillarreal',
#   'name': 'Jose Shea',
#   'sex': None,
#   'country': None,
#   'mail': 'mark86@yahoo.com',
#   'registered': None,
#   'birthdate': '2021-07-09',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1999,
#   'id': 65720,
#   'username': 'matthewsmelissa',
#   'name': 'Michelle Mathews',
#   'sex': 'F',
#   'country': None,
#   'mail': 'bbaker@gmail.com',
#   'registered': None,
#   'birthdate': '1999-02-23',
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'birth_year': 2001,
#   'id': 165933,
#   'username': 'youngoscar',
#   'name': 'Kayla Moreno',
#   'sex': 'F',
#   'country': 'Cape Verde',
#   'mail': None,
#   'registered': '2009-11-27',
#   'birthdate': '2001-01-03',
#   'name_prefix': 'Mrs.',
#   'country_code': 'CV'},
#  {'birth_year': 2016,
#   'id': 353313,
#   'username': 'montgomeryanthony',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'jsolis@hotmail.com',
#   'registered': None,
#   'birthdate': '2016-08-26',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1996,
#   'id': 1634437,
#   'username': 'batesmichael',
#   'name': None,
#   'sex': None,
#   'country': 'Cook Islands',
#   'mail': 'johnbennett@yahoo.com',
#   'registered': '2008-02-18',
#   'birthdate': '1996-01-25',
#   'name_prefix': None,
#   'country_code': 'CK'},
#  {'birth_year': 1995,
#   'id': 2000791497,
#   'username': 'kennethgregory',
#   'name': 'Melissa Frank',
#   'sex': None,
#   'country': 'Uzbekistan',
#   'mail': 'hunter46@yahoo.com',
#   'registered': None,
#   'birthdate': '1995-06-08',
#   'name_prefix': None,
#   'country_code': 'UZ'},
#  {'birth_year': 2019,
#   'id': 798070,
#   'username': 'lunaashley',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2019-12-02',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1988,
#   'id': 95743,
#   'username': 'gmorrow',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': 'brownjoseph@gmail.com',
#   'registered': '2014-05-14',
#   'birthdate': '1988-01-17',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1988,
#   'id': 464185,
#   'username': 'williamgarcia',
#   'name': 'Margaret Lopez',
#   'sex': 'F',
#   'country': None,
#   'mail': 'jenningsamy@hotmail.com',
#   'registered': None,
#   'birthdate': '1988-03-19',
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'birth_year': 2019,
#   'id': 171303,
#   'username': 'bking',
#   'name': None,
#   'sex': None,
#   'country': 'Niue',
#   'mail': 'xjones@gmail.com',
#   'registered': None,
#   'birthdate': '2019-03-26',
#   'name_prefix': None,
#   'country_code': 'NU'},
#  {'birth_year': 2011,
#   'id': 83316,
#   'username': 'ahurst',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2012-05-12',
#   'birthdate': '2011-04-08',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2014,
#   'id': 2010064,
#   'username': 'collin85',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2009-04-13',
#   'birthdate': '2014-01-17',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2018,
#   'id': 763677,
#   'username': 'feliciahenry',
#   'name': None,
#   'sex': 'M',
#   'country': 'Greece',
#   'mail': None,
#   'registered': '2013-05-24',
#   'birthdate': '2018-11-21',
#   'name_prefix': 'Mr.',
#   'country_code': 'GR'},
#  {'birth_year': 2013,
#   'id': 743937,
#   'username': 'pateljennifer',
#   'name': None,
#   'sex': None,
#   'country': 'Mexico',
#   'mail': None,
#   'registered': '2017-02-03',
#   'birthdate': '2013-02-02',
#   'name_prefix': None,
#   'country_code': 'MX'},
#  {'birth_year': 1995,
#   'id': 169430,
#   'username': 'christydavis',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': 'huntangela@hotmail.com',
#   'registered': '2012-05-26',
#   'birthdate': '1995-06-14',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1994,
#   'id': 35635,
#   'username': 'johnwright',
#   'name': None,
#   'sex': None,
#   'country': 'Iraq',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1994-10-04',
#   'name_prefix': None,
#   'country_code': 'IQ'},
#  {'birth_year': 1995,
#   'id': 20517,
#   'username': 'hernandezzachary',
#   'name': 'Brenda Williams',
#   'sex': 'F',
#   'country': 'Holy See (Vatican City State)',
#   'mail': 'morrisongail@hotmail.com',
#   'registered': '2002-02-11',
#   'birthdate': '1995-07-30',
#   'name_prefix': 'Mrs.',
#   'country_code': 'VA'},
#  {'birth_year': 1983,
#   'id': 1085140,
#   'username': 'charles22',
#   'name': None,
#   'sex': 'M',
#   'country': 'Heard Island and McDonald Islands',
#   'mail': None,
#   'registered': '2008-11-23',
#   'birthdate': '1983-07-06',
#   'name_prefix': 'Dr.',
#   'country_code': 'HM'},
#  {'birth_year': 2019,
#   'id': 2001624820,
#   'username': 'burgesschristopher',
#   'name': 'Natalie Harrell',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2019-02-03',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2004,
#   'id': 104297,
#   'username': 'greeneshannon',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'yvette19@yahoo.com',
#   'registered': '2007-01-28',
#   'birthdate': '2004-10-19',
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'birth_year': 2021,
#   'id': 47559,
#   'username': 'johnsonbrandon',
#   'name': None,
#   'sex': 'M',
#   'country': 'Guyana',
#   'mail': None,
#   'registered': None,
#   'birthdate': '2021-02-27',
#   'name_prefix': None,
#   'country_code': 'GY'},
#  {'birth_year': 1991,
#   'id': 29196,
#   'username': 'pnavarro',
#   'name': 'Evan Elliott',
#   'sex': 'M',
#   'country': None,
#   'mail': 'jrussell@yahoo.com',
#   'registered': '2010-02-13',
#   'birthdate': '1991-09-04',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'birth_year': 1985,
#   'id': 293410,
#   'username': 'icox',
#   'name': 'Justin Smith',
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2012-04-05',
#   'birthdate': '1985-05-20',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'birth_year': 2011,
#   'id': 364685,
#   'username': 'hollandrobert',
#   'name': None,
#   'sex': None,
#   'country': 'Liberia',
#   'mail': 'anita08@yahoo.com',
#   'registered': None,
#   'birthdate': '2011-04-30',
#   'name_prefix': None,
#   'country_code': 'LR'},
#  {'birth_year': 1981,
#   'id': 485940,
#   'username': 'tamara09',
#   'name': 'Carol Stone',
#   'sex': 'F',
#   'country': 'Saint Helena',
#   'mail': 'greenashley@yahoo.com',
#   'registered': None,
#   'birthdate': '1981-04-12',
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'birth_year': 2000,
#   'id': 1527940,
#   'username': 'amandafox',
#   'name': 'Leslie Lewis',
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2000-05-26',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2009,
#   'id': 678366,
#   'username': 'zgreen',
#   'name': None,
#   'sex': 'M',
#   'country': 'Bhutan',
#   'mail': None,
#   'registered': '2006-12-19',
#   'birthdate': '2009-08-07',
#   'name_prefix': None,
#   'country_code': 'BT'},
#  {'birth_year': 1999,
#   'id': 103876,
#   'username': 'perezlaura',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2019-07-28',
#   'birthdate': '1999-11-04',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'birth_year': 2017,
#   'id': 173579,
#   'username': 'eburke',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'vgibbs@hotmail.com',
#   'registered': None,
#   'birthdate': '2017-07-13',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1996,
#   'id': 953598,
#   'username': 'sherrymiller',
#   'name': 'Andrew Berg',
#   'sex': None,
#   'country': 'Bahrain',
#   'mail': None,
#   'registered': '2011-04-23',
#   'birthdate': '1996-12-10',
#   'name_prefix': None,
#   'country_code': 'BH'},
#  {'birth_year': 2017,
#   'id': 377581,
#   'username': 'martinezkendra',
#   'name': 'David Morrison',
#   'sex': None,
#   'country': 'Tokelau',
#   'mail': 'thomasthomas@yahoo.com',
#   'registered': '2003-07-20',
#   'birthdate': '2017-12-08',
#   'name_prefix': None,
#   'country_code': 'TK'},
#  {'birth_year': 1999,
#   'id': 135470,
#   'username': 'greenegabrielle',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1999-12-25',
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'birth_year': 2007,
#   'id': 2001614553,
#   'username': 'juliacochran',
#   'name': 'Patricia King',
#   'sex': None,
#   'country': None,
#   'mail': 'james67@yahoo.com',
#   'registered': None,
#   'birthdate': '2007-12-13',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2003,
#   'id': 2001495857,
#   'username': 'leecompton',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2003-06-21',
#   'birthdate': '2003-03-27',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2020,
#   'id': 1959496,
#   'username': 'fowlercarolyn',
#   'name': 'Michael Barnes',
#   'sex': 'M',
#   'country': 'Japan',
#   'mail': 'khawkins@yahoo.com',
#   'registered': None,
#   'birthdate': '2020-11-06',
#   'name_prefix': None,
#   'country_code': 'JP'},
#  {'birth_year': 2004,
#   'id': 811616,
#   'username': 'monica16',
#   'name': 'Julian Hernandez',
#   'sex': None,
#   'country': 'Jordan',
#   'mail': 'fostertimothy@gmail.com',
#   'registered': None,
#   'birthdate': '2004-04-18',
#   'name_prefix': None,
#   'country_code': 'JO'},
#  {'birth_year': 1987,
#   'id': 144798,
#   'username': 'hvaldez',
#   'name': 'Michael Bailey',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1987-05-27',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2017,
#   'id': 1020526,
#   'username': 'jeannesummers',
#   'name': 'Stephen Mckee',
#   'sex': None,
#   'country': "Cote d'Ivoire",
#   'mail': None,
#   'registered': None,
#   'birthdate': '2017-02-13',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1997,
#   'id': 37106,
#   'username': 'torrestammy',
#   'name': 'Michele House',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1997-09-09',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2008,
#   'id': 264198,
#   'username': 'thompsonjames',
#   'name': 'Michelle Gaines',
#   'sex': None,
#   'country': 'Cayman Islands',
#   'mail': None,
#   'registered': '2017-07-08',
#   'birthdate': '2008-03-10',
#   'name_prefix': None,
#   'country_code': 'KY'},
#  {'birth_year': 2017,
#   'id': 310237,
#   'username': 'stanleywright',
#   'name': None,
#   'sex': None,
#   'country': 'United Arab Emirates',
#   'mail': None,
#   'registered': '2013-02-23',
#   'birthdate': '2017-04-08',
#   'name_prefix': None,
#   'country_code': 'AE'},
#  {'birth_year': 1996,
#   'id': 62839,
#   'username': 'xmurray',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'patrickmelissa@hotmail.com',
#   'registered': None,
#   'birthdate': '1996-05-16',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2020,
#   'id': 1983947,
#   'username': 'kjones',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2020-09-11',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'birth_year': 1984,
#   'id': 131126,
#   'username': 'michael72',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': 'eparrish@yahoo.com',
#   'registered': '2006-08-06',
#   'birthdate': '1984-09-17',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1981,
#   'id': 201427,
#   'username': 'barbara14',
#   'name': 'Christopher Robbins',
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1981-11-26',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'birth_year': 1997,
#   'id': 164610,
#   'username': 'weaveranthony',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2012-11-07',
#   'birthdate': '1997-04-17',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1996,
#   'id': 37463,
#   'username': 'joshuawebb',
#   'name': 'Michael Cross',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2009-06-22',
#   'birthdate': '1996-06-20',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1994,
#   'id': 312577,
#   'username': 'dennis88',
#   'name': 'Joshua Smith',
#   'sex': 'M',
#   'country': None,
#   'mail': 'stephenburch@yahoo.com',
#   'registered': None,
#   'birthdate': '1994-10-01',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'birth_year': 2003,
#   'id': 1582575,
#   'username': 'gregorymolly',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2008-11-25',
#   'birthdate': '2003-11-09',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2021,
#   'id': 2621763,
#   'username': 'ujohnston',
#   'name': 'Kevin Moore',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2005-04-20',
#   'birthdate': '2021-04-09',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2007,
#   'id': 167369,
#   'username': 'richardchaney',
#   'name': 'Ronald Norris',
#   'sex': None,
#   'country': None,
#   'mail': 'martinsarah@gmail.com',
#   'registered': None,
#   'birthdate': '2007-10-24',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2010,
#   'id': 199792,
#   'username': 'kharris',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'campbellpaul@hotmail.com',
#   'registered': '2016-09-01',
#   'birthdate': '2010-08-11',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1991,
#   'id': 158086,
#   'username': 'anne46',
#   'name': 'Ashley Horne',
#   'sex': 'F',
#   'country': 'British Indian Ocean Territory (Chagos Archipelago)',
#   'mail': None,
#   'registered': '2015-06-19',
#   'birthdate': '1991-11-15',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1993,
#   'id': 377077,
#   'username': 'webstercarol',
#   'name': 'Amber Mcbride DVM',
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1993-07-03',
#   'name_prefix': 'Miss',
#   'country_code': None},
#  {'birth_year': 2009,
#   'id': 1098277,
#   'username': 'rjohnston',
#   'name': 'Ronald Flores',
#   'sex': None,
#   'country': 'Mauritius',
#   'mail': None,
#   'registered': '2002-05-30',
#   'birthdate': '2009-05-25',
#   'name_prefix': None,
#   'country_code': 'MU'},
#  {'birth_year': 2003,
#   'id': 312208,
#   'username': 'qsanders',
#   'name': 'Jennifer Preston',
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2003-10-23',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1987,
#   'id': 394085,
#   'username': 'zcalhoun',
#   'name': 'Mr. Roger Phelps DVM',
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2001-09-12',
#   'birthdate': '1987-07-17',
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'birth_year': 2009,
#   'id': 1052873,
#   'username': 'joseph55',
#   'name': 'Matthew Davis',
#   'sex': 'M',
#   'country': 'Burkina Faso',
#   'mail': None,
#   'registered': '2015-09-28',
#   'birthdate': '2009-07-27',
#   'name_prefix': None,
#   'country_code': 'BF'},
#  {'birth_year': 1994,
#   'id': 422893,
#   'username': 'robertagay',
#   'name': None,
#   'sex': 'M',
#   'country': 'Italy',
#   'mail': 'rodriguezralph@gmail.com',
#   'registered': None,
#   'birthdate': '1994-07-31',
#   'name_prefix': None,
#   'country_code': 'IT'},
#  {'birth_year': 2002,
#   'id': 1800137054,
#   'username': 'smithamber',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'justinmeyers@gmail.com',
#   'registered': None,
#   'birthdate': '2002-03-23',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2008,
#   'id': 620458,
#   'username': 'jennifer82',
#   'name': 'Michelle Gonzales',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2008-04-12',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2016,
#   'id': 162718,
#   'username': 'xhill',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'santiagotiffany@yahoo.com',
#   'registered': None,
#   'birthdate': '2016-05-19',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2012,
#   'id': 2654464,
#   'username': 'stewartmichael',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': 'jasoncarroll@hotmail.com',
#   'registered': None,
#   'birthdate': '2012-01-29',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'birth_year': 1996,
#   'id': 217985,
#   'username': 'mgarcia',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1996-09-22',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1982,
#   'id': 9580,
#   'username': 'kelsey58',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'jennifer23@gmail.com',
#   'registered': '2002-12-15',
#   'birthdate': '1982-09-08',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1998,
#   'id': 173838,
#   'username': 'jamesdominguez',
#   'name': 'Angela Kline',
#   'sex': None,
#   'country': 'Slovenia',
#   'mail': 'phillip39@gmail.com',
#   'registered': '2006-06-20',
#   'birthdate': '1998-07-20',
#   'name_prefix': None,
#   'country_code': 'SI'},
#  {'birth_year': 2007,
#   'id': 121497,
#   'username': 'heidiwagner',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': 'mary63@hotmail.com',
#   'registered': None,
#   'birthdate': '2007-08-06',
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'birth_year': 2016,
#   'id': 2002034744,
#   'username': 'jacksonheidi',
#   'name': 'James Wood',
#   'sex': 'M',
#   'country': 'Austria',
#   'mail': None,
#   'registered': None,
#   'birthdate': '2016-04-14',
#   'name_prefix': 'Mr.',
#   'country_code': 'AT'},
#  {'birth_year': 2006,
#   'id': 1201364,
#   'username': 'deborah82',
#   'name': 'Tammy Daniels',
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2006-04-28',
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'birth_year': 2006,
#   'id': 2001362355,
#   'username': 'casey47',
#   'name': 'Aaron Olson',
#   'sex': None,
#   'country': 'Swaziland',
#   'mail': 'jennifersmith@yahoo.com',
#   'registered': '2001-12-27',
#   'birthdate': '2006-11-10',
#   'name_prefix': None,
#   'country_code': 'SZ'},
#  {'birth_year': 2016,
#   'id': 1678798,
#   'username': 'ktran',
#   'name': 'Anthony Horne',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2016-11-21',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2013,
#   'id': 684840,
#   'username': 'curryheather',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'simpsonpam@yahoo.com',
#   'registered': '2009-05-15',
#   'birthdate': '2013-05-17',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1990,
#   'id': 380162,
#   'username': 'yblack',
#   'name': 'Jessica Cordova',
#   'sex': 'F',
#   'country': None,
#   'mail': 'harrisfrank@yahoo.com',
#   'registered': '2011-08-22',
#   'birthdate': '1990-11-09',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2016,
#   'id': 286851,
#   'username': 'lawrence24',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'spark@hotmail.com',
#   'registered': None,
#   'birthdate': '2016-07-11',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2020,
#   'id': 2740650,
#   'username': 'kellynunez',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'thomas80@gmail.com',
#   'registered': '2018-04-15',
#   'birthdate': '2020-05-06',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2012,
#   'id': 1854072,
#   'username': 'shirley85',
#   'name': 'Alan Blevins',
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2008-11-12',
#   'birthdate': '2012-10-10',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1995,
#   'id': 199848,
#   'username': 'utaylor',
#   'name': 'Tracey Wong',
#   'sex': 'F',
#   'country': 'Jamaica',
#   'mail': None,
#   'registered': '2007-06-30',
#   'birthdate': '1995-08-08',
#   'name_prefix': 'Mrs.',
#   'country_code': 'JM'},
#  {'birth_year': 2010,
#   'id': 760063,
#   'username': 'amandalang',
#   'name': 'Susan Kelly',
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2010-09-19',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1981,
#   'id': 2046,
#   'username': 'vthompson',
#   'name': 'Emily Sanford',
#   'sex': 'F',
#   'country': 'United Arab Emirates',
#   'mail': 'omelendez@yahoo.com',
#   'registered': '2001-10-30',
#   'birthdate': '1981-11-27',
#   'name_prefix': None,
#   'country_code': 'AE'},
#  {'birth_year': 2014,
#   'id': 568297,
#   'username': 'laurenbrown',
#   'name': None,
#   'sex': 'M',
#   'country': 'Bulgaria',
#   'mail': 'andrewrichards@hotmail.com',
#   'registered': None,
#   'birthdate': '2014-08-04',
#   'name_prefix': None,
#   'country_code': 'BG'},
#  {'birth_year': 2003,
#   'id': 290605,
#   'username': 'zleblanc',
#   'name': None,
#   'sex': None,
#   'country': 'Maldives',
#   'mail': None,
#   'registered': '2013-03-23',
#   'birthdate': '2003-10-19',
#   'name_prefix': None,
#   'country_code': 'MV'},
#  {'birth_year': 2011,
#   'id': 727964,
#   'username': 'yfoster',
#   'name': None,
#   'sex': 'F',
#   'country': 'Czech Republic',
#   'mail': 'lambadam@hotmail.com',
#   'registered': None,
#   'birthdate': '2011-12-07',
#   'name_prefix': None,
#   'country_code': 'CZ'},
#  {'birth_year': 1994,
#   'id': 805790,
#   'username': 'sethbuck',
#   'name': 'Matthew Fowler',
#   'sex': 'M',
#   'country': 'Congo',
#   'mail': 'veronica47@gmail.com',
#   'registered': None,
#   'birthdate': '1994-06-18',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'birth_year': 2011,
#   'id': 980570,
#   'username': 'philip24',
#   'name': None,
#   'sex': None,
#   'country': 'Jamaica',
#   'mail': None,
#   'registered': None,
#   'birthdate': '2011-02-03',
#   'name_prefix': None,
#   'country_code': 'JM'},
#  {'birth_year': 2015,
#   'id': 943857,
#   'username': 'pjames',
#   'name': 'Jacqueline Bishop',
#   'sex': None,
#   'country': None,
#   'mail': 'olynch@hotmail.com',
#   'registered': '2001-12-27',
#   'birthdate': '2015-02-27',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2013,
#   'id': 963922,
#   'username': 'fdiaz',
#   'name': 'Amy Davis',
#   'sex': None,
#   'country': None,
#   'mail': 'paulmarshall@yahoo.com',
#   'registered': None,
#   'birthdate': '2013-05-08',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2005,
#   'id': 124268,
#   'username': 'heatherwoods',
#   'name': 'Cassie Brown',
#   'sex': None,
#   'country': 'Lebanon',
#   'mail': 'margaret49@gmail.com',
#   'registered': None,
#   'birthdate': '2005-03-08',
#   'name_prefix': None,
#   'country_code': 'LB'},
#  {'birth_year': 2015,
#   'id': 406741,
#   'username': 'amandazamora',
#   'name': None,
#   'sex': 'M',
#   'country': 'French Polynesia',
#   'mail': 'ivargas@hotmail.com',
#   'registered': '2003-03-07',
#   'birthdate': '2015-09-29',
#   'name_prefix': 'Mr.',
#   'country_code': 'PF'},
#  {'birth_year': 2009,
#   'id': 452940,
#   'username': 'michaelgallegos',
#   'name': 'Susan Brown',
#   'sex': 'F',
#   'country': 'Aruba',
#   'mail': None,
#   'registered': None,
#   'birthdate': '2009-11-23',
#   'name_prefix': 'Mrs.',
#   'country_code': 'AW'},
#  {'birth_year': 2004,
#   'id': 346576,
#   'username': 'travis45',
#   'name': 'Jerome Gibson',
#   'sex': None,
#   'country': 'French Polynesia',
#   'mail': None,
#   'registered': '2019-03-06',
#   'birthdate': '2004-10-18',
#   'name_prefix': None,
#   'country_code': 'PF'},
#  {'birth_year': 1998,
#   'id': 2000547257,
#   'username': 'juliacook',
#   'name': 'Austin Callahan',
#   'sex': 'M',
#   'country': None,
#   'mail': 'sullivanjacqueline@hotmail.com',
#   'registered': None,
#   'birthdate': '1998-09-28',
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'birth_year': 1986,
#   'id': 150281,
#   'username': 'dbeard',
#   'name': None,
#   'sex': 'F',
#   'country': 'Gibraltar',
#   'mail': 'baileymelissa@hotmail.com',
#   'registered': '2011-01-25',
#   'birthdate': '1986-12-10',
#   'name_prefix': 'Dr.',
#   'country_code': 'GI'},
#  {'birth_year': 1982,
#   'id': 604874,
#   'username': 'marycobb',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'kennedynicole@hotmail.com',
#   'registered': '2006-03-07',
#   'birthdate': '1982-04-23',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1985,
#   'id': 196369,
#   'username': 'paulajenkins',
#   'name': 'Diane Jimenez',
#   'sex': 'F',
#   'country': 'Switzerland',
#   'mail': None,
#   'registered': '2001-03-07',
#   'birthdate': '1985-07-08',
#   'name_prefix': 'Mrs.',
#   'country_code': 'CH'},
#  {'birth_year': 2005,
#   'id': 1677154,
#   'username': 'darren75',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'dsmall@hotmail.com',
#   'registered': None,
#   'birthdate': '2005-10-31',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2000,
#   'id': 190425,
#   'username': 'warcher',
#   'name': None,
#   'sex': 'F',
#   'country': 'Latvia',
#   'mail': None,
#   'registered': '2014-04-25',
#   'birthdate': '2000-04-09',
#   'name_prefix': None,
#   'country_code': 'LV'},
#  {'birth_year': 2019,
#   'id': 256795,
#   'username': 'robertowood',
#   'name': None,
#   'sex': None,
#   'country': 'Saint Barthelemy',
#   'mail': 'emartin@yahoo.com',
#   'registered': '2015-08-20',
#   'birthdate': '2019-01-10',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2021,
#   'id': 22015,
#   'username': 'laura50',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'dana88@yahoo.com',
#   'registered': None,
#   'birthdate': '2021-08-05',
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'birth_year': 2009,
#   'id': 774287,
#   'username': 'fletcherthomas',
#   'name': None,
#   'sex': 'F',
#   'country': 'Brunei Darussalam',
#   'mail': 'howardwanda@gmail.com',
#   'registered': '2013-06-12',
#   'birthdate': '2009-05-23',
#   'name_prefix': 'Mrs.',
#   'country_code': 'BN'},
#  {'birth_year': 1998,
#   'id': 59753,
#   'username': 'tonya30',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2012-11-19',
#   'birthdate': '1998-06-05',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2005,
#   'id': 2002086163,
#   'username': 'garrettrichmond',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'micheal09@yahoo.com',
#   'registered': None,
#   'birthdate': '2005-03-04',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1987,
#   'id': 284897,
#   'username': 'alee',
#   'name': 'Tracy Parrish',
#   'sex': 'F',
#   'country': 'Botswana',
#   'mail': 'brianna20@yahoo.com',
#   'registered': None,
#   'birthdate': '1987-01-08',
#   'name_prefix': None,
#   'country_code': 'BW'},
#  {'birth_year': 1995,
#   'id': 945269,
#   'username': 'smithbrittany',
#   'name': 'John Smith',
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2005-02-03',
#   'birthdate': '1995-04-04',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2016,
#   'id': 224930,
#   'username': 'dianefleming',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2016-10-23',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1996,
#   'id': 456251,
#   'username': 'fordelizabeth',
#   'name': None,
#   'sex': None,
#   'country': 'Mauritania',
#   'mail': 'rodriguezjennifer@hotmail.com',
#   'registered': '2001-09-13',
#   'birthdate': '1996-05-31',
#   'name_prefix': None,
#   'country_code': 'MR'},
#  {'birth_year': 2021,
#   'id': 6512,
#   'username': 'marshallbenjamin',
#   'name': 'Brian Harding',
#   'sex': 'M',
#   'country': None,
#   'mail': 'tphillips@gmail.com',
#   'registered': '2019-01-03',
#   'birthdate': '2021-07-06',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'birth_year': 2001,
#   'id': 1179225,
#   'username': 'danagray',
#   'name': 'Erin Collins',
#   'sex': None,
#   'country': None,
#   'mail': 'christopherjohnson@gmail.com',
#   'registered': '2006-09-25',
#   'birthdate': '2001-08-31',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1997,
#   'id': 702607,
#   'username': 'adamwatkins',
#   'name': 'Rebekah Ryan',
#   'sex': None,
#   'country': None,
#   'mail': 'holderchad@gmail.com',
#   'registered': '2002-03-14',
#   'birthdate': '1997-08-27',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1982,
#   'id': 383853,
#   'username': 'williamstraci',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'brianking@hotmail.com',
#   'registered': None,
#   'birthdate': '1982-07-09',
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'birth_year': 2011,
#   'id': 41809,
#   'username': 'michellesnyder',
#   'name': 'Kathryn Mcgee',
#   'sex': None,
#   'country': 'Azerbaijan',
#   'mail': None,
#   'registered': '2003-04-01',
#   'birthdate': '2011-04-17',
#   'name_prefix': None,
#   'country_code': 'AZ'},
#  {'birth_year': 2014,
#   'id': 570804,
#   'username': 'garcialindsay',
#   'name': None,
#   'sex': 'F',
#   'country': 'Saint Martin',
#   'mail': None,
#   'registered': None,
#   'birthdate': '2014-03-19',
#   'name_prefix': 'Dr.',
#   'country_code': 'MF'},
#  {'birth_year': 2008,
#   'id': 659896,
#   'username': 'rachel58',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2011-03-16',
#   'birthdate': '2008-05-04',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1984,
#   'id': 1394505,
#   'username': 'anthonylove',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1984-02-13',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1982,
#   'id': 226863,
#   'username': 'karismith',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2011-09-15',
#   'birthdate': '1982-09-04',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1996,
#   'id': 520801,
#   'username': 'nancy68',
#   'name': None,
#   'sex': 'M',
#   'country': 'Bermuda',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1996-09-14',
#   'name_prefix': 'Dr.',
#   'country_code': 'BM'},
#  {'birth_year': 2010,
#   'id': 9748,
#   'username': 'sreeves',
#   'name': 'Janet Walters',
#   'sex': 'F',
#   'country': 'Andorra',
#   'mail': 'lowemargaret@yahoo.com',
#   'registered': '2018-07-20',
#   'birthdate': '2010-01-30',
#   'name_prefix': 'Mrs.',
#   'country_code': 'AD'},
#  {'birth_year': 2016,
#   'id': 356062,
#   'username': 'coxsheila',
#   'name': 'Robert Beltran',
#   'sex': 'M',
#   'country': 'Cayman Islands',
#   'mail': None,
#   'registered': None,
#   'birthdate': '2016-08-10',
#   'name_prefix': None,
#   'country_code': 'KY'},
#  {'birth_year': 2016,
#   'id': 526666,
#   'username': 'emily91',
#   'name': 'Michael Sullivan',
#   'sex': 'M',
#   'country': 'Zambia',
#   'mail': 'brianna08@yahoo.com',
#   'registered': None,
#   'birthdate': '2016-05-16',
#   'name_prefix': 'Dr.',
#   'country_code': 'ZM'},
#  {'birth_year': 2016,
#   'id': 251629,
#   'username': 'vanessamathis',
#   'name': 'Benjamin Villegas',
#   'sex': 'M',
#   'country': None,
#   'mail': 'garcialeslie@gmail.com',
#   'registered': None,
#   'birthdate': '2016-05-15',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2003,
#   'id': 352005,
#   'username': 'raymond53',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': 'lperry@yahoo.com',
#   'registered': None,
#   'birthdate': '2003-01-15',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'birth_year': 2006,
#   'id': 238957,
#   'username': 'thomas44',
#   'name': None,
#   'sex': None,
#   'country': 'Montserrat',
#   'mail': None,
#   'registered': None,
#   'birthdate': '2006-02-26',
#   'name_prefix': None,
#   'country_code': 'MS'},
#  {'birth_year': 2017,
#   'id': 419472,
#   'username': 'oliviaroth',
#   'name': None,
#   'sex': None,
#   'country': 'Paraguay',
#   'mail': None,
#   'registered': '2001-12-30',
#   'birthdate': '2017-05-29',
#   'name_prefix': None,
#   'country_code': 'PY'},
#  {'birth_year': 1990,
#   'id': 1193707,
#   'username': 'guzmankyle',
#   'name': 'Peter Fitzgerald',
#   'sex': 'M',
#   'country': 'Guernsey',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1990-04-09',
#   'name_prefix': 'Mr.',
#   'country_code': 'GG'},
#  {'birth_year': 2019,
#   'id': 1375473,
#   'username': 'barberpaula',
#   'name': 'Brian Larson',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2009-10-01',
#   'birthdate': '2019-09-18',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1995,
#   'id': 190230,
#   'username': 'bradchavez',
#   'name': None,
#   'sex': 'M',
#   'country': 'Saint Lucia',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1995-02-09',
#   'name_prefix': 'Mr.',
#   'country_code': 'LC'},
#  {'birth_year': 1997,
#   'id': 769846,
#   'username': 'fwilliams',
#   'name': 'Michael Church',
#   'sex': None,
#   'country': None,
#   'mail': 'angelicamckay@yahoo.com',
#   'registered': None,
#   'birthdate': '1997-01-22',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2008,
#   'id': 2143098,
#   'username': 'moorebrian',
#   'name': None,
#   'sex': None,
#   'country': 'Montenegro',
#   'mail': 'dustin66@gmail.com',
#   'registered': None,
#   'birthdate': '2008-08-17',
#   'name_prefix': None,
#   'country_code': 'ME'},
#  {'birth_year': 2018,
#   'id': 774665,
#   'username': 'uconley',
#   'name': 'Mary Wood',
#   'sex': None,
#   'country': 'Somalia',
#   'mail': 'lking@yahoo.com',
#   'registered': '2011-01-28',
#   'birthdate': '2018-10-20',
#   'name_prefix': None,
#   'country_code': 'SO'},
#  {'birth_year': 2001,
#   'id': 189616,
#   'username': 'zachary13',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': 'conwaymatthew@gmail.com',
#   'registered': '2017-10-03',
#   'birthdate': '2001-06-20',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2013,
#   'id': 1669604,
#   'username': 'thompsonraymond',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2004-09-15',
#   'birthdate': '2013-08-14',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1999,
#   'id': 114027,
#   'username': 'joshuablack',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1999-09-24',
#   'name_prefix': 'Miss',
#   'country_code': None},
#  {'birth_year': 2000,
#   'id': 489243,
#   'username': 'james28',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': 'janice10@hotmail.com',
#   'registered': None,
#   'birthdate': '2000-12-05',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'birth_year': 1987,
#   'id': 2000434581,
#   'username': 'samuelhowell',
#   'name': None,
#   'sex': None,
#   'country': 'Ukraine',
#   'mail': 'conwayheather@yahoo.com',
#   'registered': '2017-07-03',
#   'birthdate': '1987-12-10',
#   'name_prefix': None,
#   'country_code': 'UA'},
#  {'birth_year': 2016,
#   'id': 269480,
#   'username': 'hunterjennifer',
#   'name': 'Matthew Bridges',
#   'sex': None,
#   'country': 'Western Sahara',
#   'mail': 'leslie28@hotmail.com',
#   'registered': '2005-10-14',
#   'birthdate': '2016-07-07',
#   'name_prefix': None,
#   'country_code': 'EH'},
#  {'birth_year': 1984,
#   'id': 602187,
#   'username': 'patriciawest',
#   'name': 'Christopher Phillips',
#   'sex': 'M',
#   'country': 'Algeria',
#   'mail': 'clarkdaniel@gmail.com',
#   'registered': None,
#   'birthdate': '1984-12-17',
#   'name_prefix': None,
#   'country_code': 'DZ'},
#  {'birth_year': 1983,
#   'id': 200470,
#   'username': 'raymond23',
#   'name': 'Shawn Morgan',
#   'sex': None,
#   'country': 'Slovakia (Slovak Republic)',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1983-01-05',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2019,
#   'id': 284922,
#   'username': 'nelsonjames',
#   'name': 'Jessica Jones',
#   'sex': None,
#   'country': None,
#   'mail': 'evanssusan@gmail.com',
#   'registered': None,
#   'birthdate': '2019-08-02',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1984,
#   'id': 2084433,
#   'username': 'arielrasmussen',
#   'name': 'Adam Clark',
#   'sex': None,
#   'country': None,
#   'mail': 'vgriffith@yahoo.com',
#   'registered': None,
#   'birthdate': '1984-11-18',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1984,
#   'id': 306797,
#   'username': 'briansims',
#   'name': 'Jennifer Vazquez',
#   'sex': None,
#   'country': 'Tunisia',
#   'mail': 'margaret92@gmail.com',
#   'registered': '2006-12-03',
#   'birthdate': '1984-12-02',
#   'name_prefix': None,
#   'country_code': 'TN'},
#  {'birth_year': 2000,
#   'id': 27702,
#   'username': 'idavis',
#   'name': None,
#   'sex': 'M',
#   'country': 'El Salvador',
#   'mail': 'hayespatty@hotmail.com',
#   'registered': None,
#   'birthdate': '2000-10-24',
#   'name_prefix': 'Mr.',
#   'country_code': 'SV'},
#  {'birth_year': 2003,
#   'id': 285039,
#   'username': 'amymorris',
#   'name': 'Timothy Rodriguez',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2016-02-22',
#   'birthdate': '2003-03-01',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1984,
#   'id': 58104,
#   'username': 'jacquelinewheeler',
#   'name': None,
#   'sex': None,
#   'country': 'Montserrat',
#   'mail': 'tylermurphy@yahoo.com',
#   'registered': None,
#   'birthdate': '1984-04-30',
#   'name_prefix': None,
#   'country_code': 'MS'},
#  {'birth_year': 1994,
#   'id': 1803594033,
#   'username': 'vanessa47',
#   'name': None,
#   'sex': 'F',
#   'country': 'Taiwan',
#   'mail': 'francomichelle@hotmail.com',
#   'registered': None,
#   'birthdate': '1994-12-05',
#   'name_prefix': None,
#   'country_code': 'TW'},
#  {'birth_year': 2011,
#   'id': 1486423,
#   'username': 'hernandezjames',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2011-03-10',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2018,
#   'id': 177753,
#   'username': 'alec23',
#   'name': None,
#   'sex': None,
#   'country': 'Northern Mariana Islands',
#   'mail': None,
#   'registered': '2002-08-20',
#   'birthdate': '2018-05-28',
#   'name_prefix': None,
#   'country_code': 'MP'},
#  {'birth_year': 2003,
#   'id': 2001047423,
#   'username': 'maryrose',
#   'name': 'Allison Sheppard',
#   'sex': 'F',
#   'country': None,
#   'mail': 'omartinez@hotmail.com',
#   'registered': '2004-09-22',
#   'birthdate': '2003-11-07',
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'birth_year': 1990,
#   'id': 222433,
#   'username': 'christopher22',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2016-10-22',
#   'birthdate': '1990-04-04',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2017,
#   'id': 339260,
#   'username': 'reyeschristina',
#   'name': 'Jeremy Turner',
#   'sex': None,
#   'country': 'Botswana',
#   'mail': None,
#   'registered': None,
#   'birthdate': '2017-03-08',
#   'name_prefix': None,
#   'country_code': 'BW'},
#  {'birth_year': 1989,
#   'id': 223854,
#   'username': 'brendavargas',
#   'name': 'Heather Williams DDS',
#   'sex': None,
#   'country': 'Antarctica (the territory South of 60 deg S)',
#   'mail': 'aprilsims@yahoo.com',
#   'registered': '2002-09-01',
#   'birthdate': '1989-12-06',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1997,
#   'id': 818263,
#   'username': 'nsharp',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1997-06-23',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'birth_year': 2010,
#   'id': 110135,
#   'username': 'erodriguez',
#   'name': 'Jose Davila',
#   'sex': None,
#   'country': None,
#   'mail': 'brandy26@yahoo.com',
#   'registered': '2002-09-12',
#   'birthdate': '2010-04-10',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2002,
#   'id': 2000291936,
#   'username': 'tneal',
#   'name': None,
#   'sex': 'F',
#   'country': 'Monaco',
#   'mail': 'lauriefranklin@hotmail.com',
#   'registered': '2009-09-25',
#   'birthdate': '2002-03-23',
#   'name_prefix': None,
#   'country_code': 'MC'},
#  {'birth_year': 1992,
#   'id': 1510286,
#   'username': 'nzhang',
#   'name': 'Samuel Werner',
#   'sex': 'M',
#   'country': None,
#   'mail': 'dgreene@yahoo.com',
#   'registered': None,
# ...
#  {'birth_year': 2017,
#   'id': 838422,
#   'username': 'fsmith',
#   'name': 'Jean Williamson',
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2010-03-14',
#   'birthdate': '2017-03-14',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2004,
#   'id': 138462,
#   'username': 'zcastillo',
#   'name': None,
#   'sex': None,
#   'country': 'Guatemala',
#   'mail': None,
#   'registered': None,
#   'birthdate': '2004-10-16',
#   'name_prefix': None,
#   'country_code': 'GT'},
#  {'birth_year': 1993,
#   'id': 2519090,
#   'username': 'john69',
#   'name': 'Phillip Hernandez',
#   'sex': None,
#   'country': 'Montserrat',
#   'mail': None,
#   'registered': '2019-03-25',
#   'birthdate': '1993-06-20',
#   'name_prefix': None,
#   'country_code': 'MS'},
#  {'birth_year': 1984,
#   'id': 2002133744,
#   'username': 'meyerkaren',
#   'name': 'Dean Smith',
#   'sex': 'M',
#   'country': 'Liechtenstein',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1984-08-29',
#   'name_prefix': None,
#   'country_code': 'LI'},
#  {'birth_year': 1982,
#   'id': 480935,
#   'username': 'allen40',
#   'name': None,
#   'sex': 'M',
#   'country': 'Myanmar',
#   'mail': 'bowentimothy@hotmail.com',
#   'registered': None,
#   'birthdate': '1982-05-02',
#   'name_prefix': None,
#   'country_code': 'MM'},
#  {'birth_year': 2010,
#   'id': 499114,
#   'username': 'elewis',
#   'name': None,
#   'sex': 'M',
#   'country': 'Puerto Rico',
#   'mail': None,
#   'registered': None,
#   'birthdate': '2010-12-17',
#   'name_prefix': 'Mr.',
#   'country_code': 'PR'},
#  {'birth_year': 2000,
#   'id': 2002140553,
#   'username': 'daniel83',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2000-05-31',
#   'name_prefix': 'Mrs.',
#   'country_code': None},
#  {'birth_year': 1998,
#   'id': 2014756,
#   'username': 'mcdanielmary',
#   'name': 'Thomas Li',
#   'sex': 'M',
#   'country': 'Moldova',
#   'mail': 'victoriaparker@hotmail.com',
#   'registered': None,
#   'birthdate': '1998-05-15',
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'birth_year': 1993,
#   'id': 349642,
#   'username': 'jasmine03',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'nicholas78@hotmail.com',
#   'registered': '2015-10-31',
#   'birthdate': '1993-07-09',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1987,
#   'id': 205783,
#   'username': 'lewismegan',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': '2003-04-29',
#   'birthdate': '1987-07-27',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2016,
#   'id': 22724,
#   'username': 'cody85',
#   'name': 'Victoria Sandoval',
#   'sex': None,
#   'country': 'Faroe Islands',
#   'mail': 'jonesjohn@yahoo.com',
#   'registered': None,
#   'birthdate': '2016-08-23',
#   'name_prefix': None,
#   'country_code': 'FO'},
#  {'birth_year': 1992,
#   'id': 2933123,
#   'username': 'kimberly98',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'elopez@gmail.com',
#   'registered': '2002-07-09',
#   'birthdate': '1992-06-20',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2020,
#   'id': 115903,
#   'username': 'jennifermartinez',
#   'name': 'Nicholas Ingram',
#   'sex': None,
#   'country': 'Sri Lanka',
#   'mail': 'djohnson@yahoo.com',
#   'registered': '2008-06-09',
#   'birthdate': '2020-10-02',
#   'name_prefix': None,
#   'country_code': 'LK'},
#  {'birth_year': 2017,
#   'id': 659197,
#   'username': 'lking',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': 'daniellloyd@yahoo.com',
#   'registered': None,
#   'birthdate': '2017-09-05',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2019,
#   'id': 496803,
#   'username': 'jack69',
#   'name': None,
#   'sex': None,
#   'country': 'Norway',
#   'mail': None,
#   'registered': '2005-08-11',
#   'birthdate': '2019-01-16',
#   'name_prefix': None,
#   'country_code': 'NO'},
#  {'birth_year': 1985,
#   'id': 158446,
#   'username': 'joybauer',
#   'name': 'Thomas Floyd',
#   'sex': None,
#   'country': None,
#   'mail': 'robinsonnicole@gmail.com',
#   'registered': None,
#   'birthdate': '1985-01-08',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2015,
#   'id': 293796,
#   'username': 'osolomon',
#   'name': None,
#   'sex': None,
#   'country': 'Brunei Darussalam',
#   'mail': None,
#   'registered': '2006-01-19',
#   'birthdate': '2015-02-02',
#   'name_prefix': None,
#   'country_code': 'BN'},
#  {'birth_year': 1996,
#   'id': 451042,
#   'username': 'anthonylopez',
#   'name': None,
#   'sex': 'F',
#   'country': 'Greece',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1996-09-20',
#   'name_prefix': 'Miss',
#   'country_code': 'GR'},
#  {'birth_year': 1992,
#   'id': 99136,
#   'username': 'lhoward',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': 'ybailey@hotmail.com',
#   'registered': None,
#   'birthdate': '1992-08-18',
#   'name_prefix': 'Mr.',
#   'country_code': None},
#  {'birth_year': 1987,
#   'id': 1470072,
#   'username': 'john66',
#   'name': 'Paula Wagner',
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1987-03-11',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1996,
#   'id': 574666,
#   'username': 'rmiranda',
#   'name': None,
#   'sex': None,
#   'country': 'Guatemala',
#   'mail': 'raymondwilson@yahoo.com',
#   'registered': None,
#   'birthdate': '1996-07-07',
#   'name_prefix': None,
#   'country_code': 'GT'},
#  {'birth_year': 1993,
#   'id': 224235,
#   'username': 'michaelpratt',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'rodrigueztrevor@hotmail.com',
#   'registered': None,
#   'birthdate': '1993-09-16',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1998,
#   'id': 319609,
#   'username': 'jhunter',
#   'name': None,
#   'sex': 'M',
#   'country': 'Samoa',
#   'mail': 'fuentesjonathan@gmail.com',
#   'registered': '2019-04-09',
#   'birthdate': '1998-12-14',
#   'name_prefix': None,
#   'country_code': 'WS'},
#  {'birth_year': 2004,
#   'id': 184325,
#   'username': 'elizabethkirby',
#   'name': 'Patrick Brown',
#   'sex': None,
#   'country': 'Nauru',
#   'mail': 'christopher16@yahoo.com',
#   'registered': '2015-02-06',
#   'birthdate': '2004-03-09',
#   'name_prefix': None,
#   'country_code': 'NR'},
#  {'birth_year': 1991,
#   'id': 365429,
#   'username': 'wilsonjennifer',
#   'name': None,
#   'sex': 'M',
#   'country': 'Anguilla',
#   'mail': None,
#   'registered': None,
#   'birthdate': '1991-04-13',
#   'name_prefix': None,
#   'country_code': 'AI'},
#  {'birth_year': 2008,
#   'id': 1801884905,
#   'username': 'youngjonathan',
#   'name': None,
#   'sex': 'F',
#   'country': 'Falkland Islands (Malvinas)',
#   'mail': None,
#   'registered': None,
#   'birthdate': '2008-05-07',
#   'name_prefix': 'Mrs.',
#   'country_code': 'FK'},
#  {'birth_year': 1988,
#   'id': 371738,
#   'username': 'kingmary',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': 'wmckinney@gmail.com',
#   'registered': '2012-06-14',
#   'birthdate': '1988-02-24',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2004,
#   'id': 1169937,
#   'username': 'nicholas21',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2004-02-10',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2010,
#   'id': 1102578,
#   'username': 'etaylor',
#   'name': None,
#   'sex': None,
#   'country': 'Paraguay',
#   'mail': None,
#   'registered': None,
#   'birthdate': '2010-04-18',
#   'name_prefix': None,
#   'country_code': 'PY'},
#  {'birth_year': 2006,
#   'id': 793413,
#   'username': 'dylandiaz',
#   'name': None,
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': '2005-08-29',
#   'birthdate': '2006-01-13',
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'birth_year': 1987,
#   'id': 180087,
#   'username': 'martinezjeffrey',
#   'name': 'Debra Lewis',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1987-07-30',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2010,
#   'id': 1279678,
#   'username': 'tyler00',
#   'name': None,
#   'sex': None,
#   'country': 'Pitcairn Islands',
#   'mail': 'douglasstephanie@yahoo.com',
#   'registered': None,
#   'birthdate': '2010-07-17',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1997,
#   'id': 327920,
#   'username': 'sibarra',
#   'name': 'Chris Gregory',
#   'sex': None,
#   'country': 'Italy',
#   'mail': 'mcook@gmail.com',
#   'registered': None,
#   'birthdate': '1997-10-05',
#   'name_prefix': None,
#   'country_code': 'IT'},
#  {'birth_year': 1984,
#   'id': 1258695,
#   'username': 'jcarter',
#   'name': None,
#   'sex': None,
#   'country': 'Armenia',
#   'mail': None,
#   'registered': '2018-06-15',
#   'birthdate': '1984-08-20',
#   'name_prefix': None,
#   'country_code': 'AM'},
#  {'birth_year': 1992,
#   'id': 42838258,
#   'username': 'joy42',
#   'name': None,
#   'sex': 'M',
#   'country': 'Libyan Arab Jamahiriya',
#   'mail': 'jbrooks@yahoo.com',
#   'registered': '2003-01-16',
#   'birthdate': '1992-12-30',
#   'name_prefix': 'Mr.',
#   'country_code': 'LY'},
#  {'birth_year': 2004,
#   'id': 1244893,
#   'username': 'allenmarcus',
#   'name': None,
#   'sex': None,
#   'country': 'Faroe Islands',
#   'mail': 'monroechristopher@hotmail.com',
#   'registered': None,
#   'birthdate': '2004-11-27',
#   'name_prefix': None,
#   'country_code': 'FO'},
#  {'birth_year': 1987,
#   'id': 113117,
#   'username': 'iwilliamson',
#   'name': 'Tina Schmidt',
#   'sex': 'F',
#   'country': None,
#   'mail': 'whitejames@gmail.com',
#   'registered': None,
#   'birthdate': '1987-05-24',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2004,
#   'id': 872564,
#   'username': 'sean09',
#   'name': 'Donald Robinson',
#   'sex': None,
#   'country': 'Saint Pierre and Miquelon',
#   'mail': None,
#   'registered': '2007-01-28',
#   'birthdate': '2004-05-13',
#   'name_prefix': None,
#   'country_code': 'PM'},
#  {'birth_year': 2020,
#   'id': 2001710866,
#   'username': 'tsanchez',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'michael88@hotmail.com',
#   'registered': '2005-11-30',
#   'birthdate': '2020-08-31',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1998,
#   'id': 2197386,
#   'username': 'herrerajames',
#   'name': 'Melissa Hardin',
#   'sex': None,
#   'country': 'Norfolk Island',
#   'mail': None,
#   'registered': '2006-06-04',
#   'birthdate': '1998-07-28',
#   'name_prefix': None,
#   'country_code': 'NF'},
#  {'birth_year': 2002,
#   'id': 2237359,
#   'username': 'emilywoods',
#   'name': None,
#   'sex': None,
#   'country': 'Cook Islands',
#   'mail': 'cathygamble@hotmail.com',
#   'registered': '2001-05-02',
#   'birthdate': '2002-05-22',
#   'name_prefix': None,
#   'country_code': 'CK'},
#  {'birth_year': 1988,
#   'id': 565650,
#   'username': 'stephanieflores',
#   'name': None,
#   'sex': 'M',
#   'country': 'Falkland Islands (Malvinas)',
#   'mail': 'natalie35@yahoo.com',
#   'registered': None,
#   'birthdate': '1988-03-31',
#   'name_prefix': None,
#   'country_code': 'FK'},
#  {'birth_year': 1984,
#   'id': 449482,
#   'username': 'sylvia29',
#   'name': 'Eric Lewis',
#   'sex': 'M',
#   'country': 'South Georgia and the South Sandwich Islands',
#   'mail': 'todd80@yahoo.com',
#   'registered': None,
#   'birthdate': '1984-04-17',
#   'name_prefix': 'Mr.',
#   'country_code': 'GS'},
#  {'birth_year': 2014,
#   'id': 29418,
#   'username': 'angelicakemp',
#   'name': None,
#   'sex': 'M',
#   'country': 'Indonesia',
#   'mail': 'wduran@yahoo.com',
#   'registered': None,
#   'birthdate': '2014-02-12',
#   'name_prefix': 'Mr.',
#   'country_code': 'ID'},
#  {'birth_year': 1995,
#   'id': 852554,
#   'username': 'ashleyrichards',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2015-08-24',
#   'birthdate': '1995-01-02',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2013,
#   'id': 34879,
#   'username': 'creyes',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': 'apriljones@yahoo.com',
#   'registered': '2003-10-23',
#   'birthdate': '2013-04-26',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1999,
#   'id': 633520,
#   'username': 'roweeric',
#   'name': None,
#   'sex': 'F',
#   'country': 'South Africa',
#   'mail': 'nicholasbrooks@hotmail.com',
#   'registered': None,
#   'birthdate': '1999-07-13',
#   'name_prefix': 'Mrs.',
#   'country_code': 'ZA'},
#  {'birth_year': 1990,
#   'id': 229283,
#   'username': 'jnorton',
#   'name': 'Sarah Butler',
#   'sex': None,
#   'country': None,
#   'mail': 'paulbird@yahoo.com',
#   'registered': None,
#   'birthdate': '1990-03-02',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2018,
#   'id': 991523,
#   'username': 'lbell',
#   'name': None,
#   'sex': 'M',
#   'country': None,
#   'mail': 'pmontgomery@yahoo.com',
#   'registered': None,
#   'birthdate': '2018-08-31',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2016,
#   'id': 1403040,
#   'username': 'tbrown',
#   'name': 'Matthew Pittman',
#   'sex': 'M',
#   'country': 'Macao',
#   'mail': None,
#   'registered': None,
#   'birthdate': '2016-11-24',
#   'name_prefix': 'Mr.',
#   'country_code': 'MO'},
#  {'birth_year': 1997,
#   'id': 50712,
#   'username': 'huntrebecca',
#   'name': 'Dawn Myers',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '1997-06-23',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1981,
#   'id': 92968,
#   'username': 'benjaminhuffman',
#   'name': 'Daniel Walton',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2015-12-18',
#   'birthdate': '1981-05-08',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2017,
#   'id': 223978,
#   'username': 'sylviajohnson',
#   'name': 'Stephanie Rivera',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2005-03-19',
#   'birthdate': '2017-05-06',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2001,
#   'id': 1948802,
#   'username': 'tamara74',
#   'name': None,
#   'sex': 'M',
#   'country': 'Turks and Caicos Islands',
#   'mail': None,
#   'registered': '2008-06-15',
#   'birthdate': '2001-01-21',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2005,
#   'id': 222696,
#   'username': 'brianjones',
#   'name': 'Heidi Silva',
#   'sex': 'F',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2005-07-31',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1984,
#   'id': 457829,
#   'username': 'roger44',
#   'name': None,
#   'sex': None,
#   'country': 'Tuvalu',
#   'mail': 'gsmith@hotmail.com',
#   'registered': None,
#   'birthdate': '1984-07-08',
#   'name_prefix': None,
#   'country_code': 'TV'},
#  {'birth_year': 1992,
#   'id': 213049,
#   'username': 'elizabeth28',
#   'name': None,
#   'sex': None,
#   'country': 'Maldives',
#   'mail': None,
#   'registered': '2012-08-19',
#   'birthdate': '1992-12-02',
#   'name_prefix': None,
#   'country_code': 'MV'},
#  {'birth_year': 2008,
#   'id': 737575,
#   'username': 'nhernandez',
#   'name': 'Wendy Castaneda',
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': '2015-03-14',
#   'birthdate': '2008-02-21',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 1991,
#   'id': 355885,
#   'username': 'darrelldavis',
#   'name': 'Jason Garcia',
#   'sex': 'M',
#   'country': 'Sweden',
#   'mail': None,
#   'registered': '2001-06-06',
#   'birthdate': '1991-12-04',
#   'name_prefix': 'Mr.',
#   'country_code': 'SE'},
#  {'birth_year': 1991,
#   'id': 1803607509,
#   'username': 'joelmartin',
#   'name': 'Kevin West',
#   'sex': None,
#   'country': 'Bolivia',
#   'mail': 'melissabennett@gmail.com',
#   'registered': '2007-12-16',
#   'birthdate': '1991-01-26',
#   'name_prefix': None,
#   'country_code': 'BO'},
#  {'birth_year': 2014,
#   'id': 129422,
#   'username': 'melissarivera',
#   'name': None,
#   'sex': None,
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2014-03-24',
#   'name_prefix': None,
#   'country_code': None},
#  {'birth_year': 2018,
#   'id': 11989,
#   'username': 'plopez',
#   'name': 'Anthony Johnson',
#   'sex': 'M',
#   'country': None,
#   'mail': None,
#   'registered': None,
#   'birthdate': '2018-05-30',
#   'name_prefix': 'Dr.',
#   'country_code': None},
#  {'birth_year': 1986,
#   'id': 914720,
#   'username': 'mariah13',
#   'name': 'Amanda Carr',
#   'sex': 'F',
#   'country': None,
#   'mail': 'rhondahansen@hotmail.com',
#   'registered': '2011-06-13',
#   'birthdate': '1986-12-12',
#   'name_prefix': 'Ms.',
#   'country_code': None},
#  ...]

# %% [markdown]
# 4. Из `dask.bag`, полученного в задании 3, создайте `dask.dataframe` при помощи метода `bag.to_dataframe`. Укажите столбец `id` в качестве индекса.

# %%
df4 = b.to_dataframe().set_index('id').compute()

# %%
df4
# Out:
#             birth_year       username              name   sex  \
# id
# 1676              1983        lgeorge              None     M
# 1792              1986         qbeard              None     F
# 1938              1991      adambrown    William Fisher  None
# 2046              1981      vthompson     Emily Sanford     F
# 2095              1984       djohnson  Jennifer Hawkins     F
# ...                ...            ...               ...   ...
# 2002370648        2010      wbradford              None  None
# 2002371420        1994  walkershirley     Travis Harris     M
# 2002371627        2000    travisbrown              None  None
# 2002371716        2007          greid         Jose Mata  None
# 2002372706        2007  gibbsnicholas    Jeffrey Rivera     M
#
#                          country                  mail  registered  \
# id
# 1676                        None                  None        None
# 1792                      Guinea  rachel20@hotmail.com        None
# 1938               New Caledonia                  None  2019-05-03
# 2046        United Arab Emirates   omelendez@yahoo.com  2001-10-30
# 2095                     Jamaica                  None        None
# ...                          ...                   ...         ...
# 2002370648                  None                  None        None
# 2002371420               Vietnam                  None  2009-08-15
# 2002371627                  None      kdoyle@gmail.com  2005-03-10
# 2002371716             Lithuania                  None  2002-01-06
# 2002372706             Greenland    thomas67@gmail.com  2018-07-25
#
#              birthdate name_prefix country_code
# id
# 1676        1983-06-24        None         None
# 1792        1986-03-12        None           GN
# 1938        1991-11-11        None           NC
# 2046        1981-11-27        None           AE
# 2095        1984-09-23        Mrs.           JM
# ...                ...         ...          ...
# 2002370648  2010-07-14        None         None
# 2002371420  1994-02-16         Mr.           VN
# 2002371627  2000-06-11        None         None
# 2002371716  2007-07-01        None           LT
# 2002372706  2007-05-20        None           GL
#
# [64088 rows x 10 columns]

# %% [markdown]
# 5. Назовем отзыв негативным, если оценка равна 0, 1 или 2. Загрузите данные о негативных отзывах из файлов архива `reviews_full` (__ЛР12__) в виде `dask.DataFrame`. Посчитайте количество отзывов с группировкой по пользователю, оставившему отзыв. Объедините результат с таблицей, полученной в задаче 4.

# %%
import dask.dataframe as dd
def modifiedLoads(x):
  dct = json.loads(x[0])
  dct["rating"] = int(x[1][-6])
  return dct

bag = db.read_text("/content/drive/MyDrive/tobd/reviews_full/reviews_*.json", include_path=True).map(modifiedLoads)
df = bag.to_dataframe()
df = df[df["rating"] < 3]
count = df.groupby('user_id')['rating'].count().compute()

# %%
dd.concat([df4, count.to_frame()], axis=1).dropna().compute()
# Out:
#             birth_year           username              name sex  \
# 2178            1985.0       michaeljones  Anthony Santiago   M
# 2611            1982.0       graymargaret       Leah Brooks   F
# 9748            2010.0            sreeves     Janet Walters   F
# 10054           1983.0       whiterichard    Patrick Hinton   M
# 12678           2018.0      evansjonathon    Douglas Thomas   M
# ...                ...                ...               ...  ..
# 2002254771      2008.0  michellearmstrong     Connie Carter   F
# 2002268118      2014.0           ledwards   Kristin Stanley   F
# 2002337783      2013.0             kjones      Tanya Porter   F
# 2002348851      2004.0     thompsonjoshua   Melissa Jackson   F
# 2002348897      2013.0           lijoshua      Amanda Allen   F
#
#                      country                      mail  registered  \
# 2178                   Haiti   jessicaharris@gmail.com  2013-12-12
# 2611                 Ireland   gomezangela@hotmail.com  2011-08-04
# 9748                 Andorra    lowemargaret@yahoo.com  2018-07-20
# 10054                  Palau         brian76@gmail.com  2002-01-13
# 12678                Namibia    donaldpierce@yahoo.com  2013-03-04
# ...                      ...                       ...         ...
# 2002254771  Marshall Islands     rebekahkerr@yahoo.com  2003-05-19
# 2002268118           Ireland     patrick22@hotmail.com  2005-10-07
# 2002337783           Denmark         kgreene@gmail.com  2007-03-17
# 2002348851           Bahrain  michaelmccoy@hotmail.com  2018-08-20
# 2002348897  Christmas Island      theodore05@yahoo.com  2018-09-01
#
#              birthdate name_prefix country_code  rating
# 2178        1985-08-12         Mr.           HT    20.0
# 2611        1982-03-01         Ms.           IE     3.0
# 9748        2010-01-30        Mrs.           AD    88.0
# 10054       1983-03-20         Mr.           PW     3.0
# 12678       2018-01-14         Mr.          nan     2.0
# ...                ...         ...          ...     ...
# 2002254771  2008-06-10         Dr.           MH     1.0
# 2002268118  2014-02-12        Mrs.           IE     6.0
# 2002337783  2013-03-06         Dr.           DK     1.0
# 2002348851  2004-09-07        Mrs.           BH     1.0
# 2002348897  2013-12-25        Mrs.           CX     1.0
#
# [613 rows x 11 columns]
